# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.random.normal(size=(6,6)),
                  columns=[x for x in "ABCDEF"])

# %%
df
# Out:
#           A         B         C         D         E         F
# 0  0.333345 -0.629803  0.969120 -0.552186  2.045531  0.493451
# 1 -2.247491 -0.583168  0.772002 -0.539848  0.685423 -0.026424
# 2  1.340672 -2.274927  0.580671 -0.496357 -0.869345 -0.303273
# 3 -0.669154 -1.384254 -0.554533  0.222029  1.490304 -0.207517
# 4  1.384573  1.921515 -2.620463 -1.677286 -0.132911 -0.791548
# 5  0.981818 -1.734554 -0.262190  2.427322  0.113008  0.694343

# %%
def neg_red(x):
    return f"color:{'red' if x < 0 else 'blcck'}"

# %%
df.style.applymap(neg_red)
# Out:
# <style  type="text/css" >
# #T_baa17_row0_col0,#T_baa17_row0_col2,#T_baa17_row0_col4,#T_baa17_row0_col5,#T_baa17_row1_col2,#T_baa17_row1_col4,#T_baa17_row2_col0,#T_baa17_row2_col2,#T_baa17_row3_col3,#T_baa17_row3_col4,#T_baa17_row4_col0,#T_baa17_row4_col1,#T_baa17_row5_col0,#T_baa17_row5_col3,#T_baa17_row5_col4,#T_baa17_row5_col5{
#             color: blcck;
#         }#T_baa17_row0_col1,#T_baa17_row0_col3,#T_baa17_row1_col0,#T_baa17_row1_col1,#T_baa17_row1_col3,#T_baa17_row1_col5,#T_baa17_row2_col1,#T_baa17_row2_col3,#T_baa17_row2_col4,#T_baa17_row2_col5,#T_baa17_row3_col0,#T_baa17_row3_col1,#T_baa17_row3_col2,#T_baa17_row3_col5,#T_baa17_row4_col2,#T_baa17_row4_col3,#T_baa17_row4_col4,#T_baa17_row4_col5,#T_baa17_row5_col1,#T_baa17_row5_col2{
#             color: red;
#         }</style><table id="T_baa17_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>        <th class="col_heading level0 col5" >F</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_baa17_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_baa17_row0_col0" class="data row0 col0" >0.333345</td>
#                         <td id="T_baa17_row0_col1" class="data row0 col1" >-0.629803</td>
#                         <td id="T_baa17_row0_col2" class="data row0 col2" >0.969120</td>
#                         <td id="T_baa17_row0_col3" class="data row0 col3" >-0.552186</td>
#                         <td id="T_baa17_row0_col4" class="data row0 col4" >2.045531</td>
#                         <td id="T_baa17_row0_col5" class="data row0 col5" >0.493451</td>
#             </tr>
#             <tr>
#                         <th id="T_baa17_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_baa17_row1_col0" class="data row1 col0" >-2.247491</td>
#                         <td id="T_baa17_row1_col1" class="data row1 col1" >-0.583168</td>
#                         <td id="T_baa17_row1_col2" class="data row1 col2" >0.772002</td>
#                         <td id="T_baa17_row1_col3" class="data row1 col3" >-0.539848</td>
#                         <td id="T_baa17_row1_col4" class="data row1 col4" >0.685423</td>
#                         <td id="T_baa17_row1_col5" class="data row1 col5" >-0.026424</td>
#             </tr>
#             <tr>
#                         <th id="T_baa17_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_baa17_row2_col0" class="data row2 col0" >1.340672</td>
#                         <td id="T_baa17_row2_col1" class="data row2 col1" >-2.274927</td>
#                         <td id="T_baa17_row2_col2" class="data row2 col2" >0.580671</td>
#                         <td id="T_baa17_row2_col3" class="data row2 col3" >-0.496357</td>
#                         <td id="T_baa17_row2_col4" class="data row2 col4" >-0.869345</td>
#                         <td id="T_baa17_row2_col5" class="data row2 col5" >-0.303273</td>
#             </tr>
#             <tr>
#                         <th id="T_baa17_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_baa17_row3_col0" class="data row3 col0" >-0.669154</td>
#                         <td id="T_baa17_row3_col1" class="data row3 col1" >-1.384254</td>
#                         <td id="T_baa17_row3_col2" class="data row3 col2" >-0.554533</td>
#                         <td id="T_baa17_row3_col3" class="data row3 col3" >0.222029</td>
#                         <td id="T_baa17_row3_col4" class="data row3 col4" >1.490304</td>
#                         <td id="T_baa17_row3_col5" class="data row3 col5" >-0.207517</td>
#             </tr>
#             <tr>
#                         <th id="T_baa17_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_baa17_row4_col0" class="data row4 col0" >1.384573</td>
#                         <td id="T_baa17_row4_col1" class="data row4 col1" >1.921515</td>
#                         <td id="T_baa17_row4_col2" class="data row4 col2" >-2.620463</td>
#                         <td id="T_baa17_row4_col3" class="data row4 col3" >-1.677286</td>
#                         <td id="T_baa17_row4_col4" class="data row4 col4" >-0.132911</td>
#                         <td id="T_baa17_row4_col5" class="data row4 col5" >-0.791548</td>
#             </tr>
#             <tr>
#                         <th id="T_baa17_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_baa17_row5_col0" class="data row5 col0" >0.981818</td>
#                         <td id="T_baa17_row5_col1" class="data row5 col1" >-1.734554</td>
#                         <td id="T_baa17_row5_col2" class="data row5 col2" >-0.262190</td>
#                         <td id="T_baa17_row5_col3" class="data row5 col3" >2.427322</td>
#                         <td id="T_baa17_row5_col4" class="data row5 col4" >0.113008</td>
#                         <td id="T_baa17_row5_col5" class="data row5 col5" >0.694343</td>
#             </tr>
#     </tbody></table>

# %%
def gold_max(xs):
    m = xs.to_numpy().max()
    color = {True : "background-color: #c78f2e", False:""}
    is_max = (xs == m).replace(color)
    return is_max

# %%
df.style.apply(gold_max, axis=None)
# Out:
# <style  type="text/css" >
# #T_6dee9_row5_col3{
#             background-color:  #c78f2e;
#         }</style><table id="T_6dee9_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>        <th class="col_heading level0 col5" >F</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6dee9_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6dee9_row0_col0" class="data row0 col0" >0.333345</td>
#                         <td id="T_6dee9_row0_col1" class="data row0 col1" >-0.629803</td>
#                         <td id="T_6dee9_row0_col2" class="data row0 col2" >0.969120</td>
#                         <td id="T_6dee9_row0_col3" class="data row0 col3" >-0.552186</td>
#                         <td id="T_6dee9_row0_col4" class="data row0 col4" >2.045531</td>
#                         <td id="T_6dee9_row0_col5" class="data row0 col5" >0.493451</td>
#             </tr>
#             <tr>
#                         <th id="T_6dee9_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6dee9_row1_col0" class="data row1 col0" >-2.247491</td>
#                         <td id="T_6dee9_row1_col1" class="data row1 col1" >-0.583168</td>
#                         <td id="T_6dee9_row1_col2" class="data row1 col2" >0.772002</td>
#                         <td id="T_6dee9_row1_col3" class="data row1 col3" >-0.539848</td>
#                         <td id="T_6dee9_row1_col4" class="data row1 col4" >0.685423</td>
#                         <td id="T_6dee9_row1_col5" class="data row1 col5" >-0.026424</td>
#             </tr>
#             <tr>
#                         <th id="T_6dee9_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6dee9_row2_col0" class="data row2 col0" >1.340672</td>
#                         <td id="T_6dee9_row2_col1" class="data row2 col1" >-2.274927</td>
#                         <td id="T_6dee9_row2_col2" class="data row2 col2" >0.580671</td>
#                         <td id="T_6dee9_row2_col3" class="data row2 col3" >-0.496357</td>
#                         <td id="T_6dee9_row2_col4" class="data row2 col4" >-0.869345</td>
#                         <td id="T_6dee9_row2_col5" class="data row2 col5" >-0.303273</td>
#             </tr>
#             <tr>
#                         <th id="T_6dee9_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6dee9_row3_col0" class="data row3 col0" >-0.669154</td>
#                         <td id="T_6dee9_row3_col1" class="data row3 col1" >-1.384254</td>
#                         <td id="T_6dee9_row3_col2" class="data row3 col2" >-0.554533</td>
#                         <td id="T_6dee9_row3_col3" class="data row3 col3" >0.222029</td>
#                         <td id="T_6dee9_row3_col4" class="data row3 col4" >1.490304</td>
#                         <td id="T_6dee9_row3_col5" class="data row3 col5" >-0.207517</td>
#             </tr>
#             <tr>
#                         <th id="T_6dee9_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6dee9_row4_col0" class="data row4 col0" >1.384573</td>
#                         <td id="T_6dee9_row4_col1" class="data row4 col1" >1.921515</td>
#                         <td id="T_6dee9_row4_col2" class="data row4 col2" >-2.620463</td>
#                         <td id="T_6dee9_row4_col3" class="data row4 col3" >-1.677286</td>
#                         <td id="T_6dee9_row4_col4" class="data row4 col4" >-0.132911</td>
#                         <td id="T_6dee9_row4_col5" class="data row4 col5" >-0.791548</td>
#             </tr>
#             <tr>
#                         <th id="T_6dee9_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6dee9_row5_col0" class="data row5 col0" >0.981818</td>
#                         <td id="T_6dee9_row5_col1" class="data row5 col1" >-1.734554</td>
#                         <td id="T_6dee9_row5_col2" class="data row5 col2" >-0.262190</td>
#                         <td id="T_6dee9_row5_col3" class="data row5 col3" >2.427322</td>
#                         <td id="T_6dee9_row5_col4" class="data row5 col4" >0.113008</td>
#                         <td id="T_6dee9_row5_col5" class="data row5 col5" >0.694343</td>
#             </tr>
#     </tbody></table>

# %%
df.style.background_gradient(cmap="magma")
# Out:
# <style  type="text/css" >
# #T_773ae_row0_col0{
#             background-color:  #f8745c;
#             color:  #000000;
#         }#T_773ae_row0_col1,#T_773ae_row3_col5{
#             background-color:  #892881;
#             color:  #f1f1f1;
#         }#T_773ae_row0_col2,#T_773ae_row0_col4,#T_773ae_row4_col0,#T_773ae_row4_col1,#T_773ae_row5_col3,#T_773ae_row5_col5{
#             background-color:  #fcfdbf;
#             color:  #000000;
#         }#T_773ae_row0_col3,#T_773ae_row1_col3{
#             background-color:  #5a167e;
#             color:  #f1f1f1;
#         }#T_773ae_row0_col5{
#             background-color:  #febf84;
#             color:  #000000;
#         }#T_773ae_row1_col0,#T_773ae_row2_col1,#T_773ae_row2_col4,#T_773ae_row4_col2,#T_773ae_row4_col3,#T_773ae_row4_col5{
#             background-color:  #000004;
#             color:  #f1f1f1;
#         }#T_773ae_row1_col1{
#             background-color:  #8e2a81;
#             color:  #f1f1f1;
#         }#T_773ae_row1_col2{
#             background-color:  #fde3a5;
#             color:  #000000;
#         }#T_773ae_row1_col4{
#             background-color:  #c43c75;
#             color:  #f1f1f1;
#         }#T_773ae_row1_col5{
#             background-color:  #bc3978;
#             color:  #f1f1f1;
#         }#T_773ae_row2_col0{
#             background-color:  #fcf7b9;
#             color:  #000000;
#         }#T_773ae_row2_col2{
#             background-color:  #fecc8f;
#             color:  #000000;
#         }#T_773ae_row2_col3{
#             background-color:  #5f187f;
#             color:  #f1f1f1;
#         }#T_773ae_row2_col5{
#             background-color:  #701f81;
#             color:  #f1f1f1;
#         }#T_773ae_row3_col0{
#             background-color:  #9b2e7f;
#             color:  #f1f1f1;
#         }#T_773ae_row3_col1{
#             background-color:  #400f74;
#             color:  #f1f1f1;
#         }#T_773ae_row3_col2{
#             background-color:  #d5446d;
#             color:  #f1f1f1;
#         }#T_773ae_row3_col3{
#             background-color:  #a6317d;
#             color:  #f1f1f1;
#         }#T_773ae_row3_col4{
#             background-color:  #fea571;
#             color:  #000000;
#         }#T_773ae_row4_col4{
#             background-color:  #51127c;
#             color:  #f1f1f1;
#         }#T_773ae_row5_col0{
#             background-color:  #feca8d;
#             color:  #000000;
#         }#T_773ae_row5_col1{
#             background-color:  #1d1147;
#             color:  #f1f1f1;
#         }#T_773ae_row5_col2{
#             background-color:  #ef5d5e;
#             color:  #000000;
#         }#T_773ae_row5_col4{
#             background-color:  #732081;
#             color:  #f1f1f1;
#         }</style><table id="T_773ae_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>        <th class="col_heading level0 col5" >F</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_773ae_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_773ae_row0_col0" class="data row0 col0" >0.333345</td>
#                         <td id="T_773ae_row0_col1" class="data row0 col1" >-0.629803</td>
#                         <td id="T_773ae_row0_col2" class="data row0 col2" >0.969120</td>
#                         <td id="T_773ae_row0_col3" class="data row0 col3" >-0.552186</td>
#                         <td id="T_773ae_row0_col4" class="data row0 col4" >2.045531</td>
#                         <td id="T_773ae_row0_col5" class="data row0 col5" >0.493451</td>
#             </tr>
#             <tr>
#                         <th id="T_773ae_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_773ae_row1_col0" class="data row1 col0" >-2.247491</td>
#                         <td id="T_773ae_row1_col1" class="data row1 col1" >-0.583168</td>
#                         <td id="T_773ae_row1_col2" class="data row1 col2" >0.772002</td>
#                         <td id="T_773ae_row1_col3" class="data row1 col3" >-0.539848</td>
#                         <td id="T_773ae_row1_col4" class="data row1 col4" >0.685423</td>
#                         <td id="T_773ae_row1_col5" class="data row1 col5" >-0.026424</td>
#             </tr>
#             <tr>
#                         <th id="T_773ae_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_773ae_row2_col0" class="data row2 col0" >1.340672</td>
#                         <td id="T_773ae_row2_col1" class="data row2 col1" >-2.274927</td>
#                         <td id="T_773ae_row2_col2" class="data row2 col2" >0.580671</td>
#                         <td id="T_773ae_row2_col3" class="data row2 col3" >-0.496357</td>
#                         <td id="T_773ae_row2_col4" class="data row2 col4" >-0.869345</td>
#                         <td id="T_773ae_row2_col5" class="data row2 col5" >-0.303273</td>
#             </tr>
#             <tr>
#                         <th id="T_773ae_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_773ae_row3_col0" class="data row3 col0" >-0.669154</td>
#                         <td id="T_773ae_row3_col1" class="data row3 col1" >-1.384254</td>
#                         <td id="T_773ae_row3_col2" class="data row3 col2" >-0.554533</td>
#                         <td id="T_773ae_row3_col3" class="data row3 col3" >0.222029</td>
#                         <td id="T_773ae_row3_col4" class="data row3 col4" >1.490304</td>
#                         <td id="T_773ae_row3_col5" class="data row3 col5" >-0.207517</td>
#             </tr>
#             <tr>
#                         <th id="T_773ae_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_773ae_row4_col0" class="data row4 col0" >1.384573</td>
#                         <td id="T_773ae_row4_col1" class="data row4 col1" >1.921515</td>
#                         <td id="T_773ae_row4_col2" class="data row4 col2" >-2.620463</td>
#                         <td id="T_773ae_row4_col3" class="data row4 col3" >-1.677286</td>
#                         <td id="T_773ae_row4_col4" class="data row4 col4" >-0.132911</td>
#                         <td id="T_773ae_row4_col5" class="data row4 col5" >-0.791548</td>
#             </tr>
#             <tr>
#                         <th id="T_773ae_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_773ae_row5_col0" class="data row5 col0" >0.981818</td>
#                         <td id="T_773ae_row5_col1" class="data row5 col1" >-1.734554</td>
#                         <td id="T_773ae_row5_col2" class="data row5 col2" >-0.262190</td>
#                         <td id="T_773ae_row5_col3" class="data row5 col3" >2.427322</td>
#                         <td id="T_773ae_row5_col4" class="data row5 col4" >0.113008</td>
#                         <td id="T_773ae_row5_col5" class="data row5 col5" >0.694343</td>
#             </tr>
#     </tbody></table>

# %%
df.abs().style.bar(align="left", width=90)
# Out:
# <style  type="text/css" >
# #T_4e890_row0_col0,#T_4e890_row1_col1,#T_4e890_row1_col5,#T_4e890_row3_col3,#T_4e890_row5_col2,#T_4e890_row5_col4{
#             width:  10em;
#              height:  80%;
#         }#T_4e890_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.5%, transparent 2.5%);
#         }#T_4e890_row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 27.0%, transparent 27.0%);
#         }#T_4e890_row0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.5%, transparent 13.5%);
#         }#T_4e890_row0_col4,#T_4e890_row1_col0,#T_4e890_row2_col1,#T_4e890_row4_col2,#T_4e890_row4_col5,#T_4e890_row5_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 90.0%, transparent 90.0%);
#         }#T_4e890_row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 54.9%, transparent 54.9%);
#         }#T_4e890_row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.5%, transparent 19.5%);
#         }#T_4e890_row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.0%, transparent 13.0%);
#         }#T_4e890_row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.7%, transparent 26.7%);
#         }#T_4e890_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 47.4%, transparent 47.4%);
#         }#T_4e890_row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.2%, transparent 12.2%);
#         }#T_4e890_row2_col3,#T_4e890_row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.2%, transparent 11.2%);
#         }#T_4e890_row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 35.2%, transparent 35.2%);
#         }#T_4e890_row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 32.6%, transparent 32.6%);
#         }#T_4e890_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.8%, transparent 15.8%);
#         }#T_4e890_row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 42.6%, transparent 42.6%);
#         }#T_4e890_row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 64.1%, transparent 64.1%);
#         }#T_4e890_row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 21.3%, transparent 21.3%);
#         }#T_4e890_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 49.4%, transparent 49.4%);
#         }#T_4e890_row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 71.2%, transparent 71.2%);
#         }#T_4e890_row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 59.4%, transparent 59.4%);
#         }#T_4e890_row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.9%, transparent 0.9%);
#         }#T_4e890_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 30.5%, transparent 30.5%);
#         }#T_4e890_row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 61.3%, transparent 61.3%);
#         }#T_4e890_row5_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 78.6%, transparent 78.6%);
#         }</style><table id="T_4e890_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>        <th class="col_heading level0 col5" >F</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4e890_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4e890_row0_col0" class="data row0 col0" >0.333345</td>
#                         <td id="T_4e890_row0_col1" class="data row0 col1" >0.629803</td>
#                         <td id="T_4e890_row0_col2" class="data row0 col2" >0.969120</td>
#                         <td id="T_4e890_row0_col3" class="data row0 col3" >0.552186</td>
#                         <td id="T_4e890_row0_col4" class="data row0 col4" >2.045531</td>
#                         <td id="T_4e890_row0_col5" class="data row0 col5" >0.493451</td>
#             </tr>
#             <tr>
#                         <th id="T_4e890_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_4e890_row1_col0" class="data row1 col0" >2.247491</td>
#                         <td id="T_4e890_row1_col1" class="data row1 col1" >0.583168</td>
#                         <td id="T_4e890_row1_col2" class="data row1 col2" >0.772002</td>
#                         <td id="T_4e890_row1_col3" class="data row1 col3" >0.539848</td>
#                         <td id="T_4e890_row1_col4" class="data row1 col4" >0.685423</td>
#                         <td id="T_4e890_row1_col5" class="data row1 col5" >0.026424</td>
#             </tr>
#             <tr>
#                         <th id="T_4e890_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_4e890_row2_col0" class="data row2 col0" >1.340672</td>
#                         <td id="T_4e890_row2_col1" class="data row2 col1" >2.274927</td>
#                         <td id="T_4e890_row2_col2" class="data row2 col2" >0.580671</td>
#                         <td id="T_4e890_row2_col3" class="data row2 col3" >0.496357</td>
#                         <td id="T_4e890_row2_col4" class="data row2 col4" >0.869345</td>
#                         <td id="T_4e890_row2_col5" class="data row2 col5" >0.303273</td>
#             </tr>
#             <tr>
#                         <th id="T_4e890_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_4e890_row3_col0" class="data row3 col0" >0.669154</td>
#                         <td id="T_4e890_row3_col1" class="data row3 col1" >1.384254</td>
#                         <td id="T_4e890_row3_col2" class="data row3 col2" >0.554533</td>
#                         <td id="T_4e890_row3_col3" class="data row3 col3" >0.222029</td>
#                         <td id="T_4e890_row3_col4" class="data row3 col4" >1.490304</td>
#                         <td id="T_4e890_row3_col5" class="data row3 col5" >0.207517</td>
#             </tr>
#             <tr>
#                         <th id="T_4e890_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_4e890_row4_col0" class="data row4 col0" >1.384573</td>
#                         <td id="T_4e890_row4_col1" class="data row4 col1" >1.921515</td>
#                         <td id="T_4e890_row4_col2" class="data row4 col2" >2.620463</td>
#                         <td id="T_4e890_row4_col3" class="data row4 col3" >1.677286</td>
#                         <td id="T_4e890_row4_col4" class="data row4 col4" >0.132911</td>
#                         <td id="T_4e890_row4_col5" class="data row4 col5" >0.791548</td>
#             </tr>
#             <tr>

# %%
head = {"selector": "th", "props": [("text-align", "center")]}
df.style.set_table_styles([head]).bar(align="mid", color=['red', 'green'], vmin=-3, vmax=3)
# Out:
# <style  type="text/css" >
#     #T_82fb0_ th {
#           text-align: center;
#     }#T_82fb0_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 55.6%, transparent 55.6%);
#         }#T_82fb0_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 39.5%, red 39.5%, red 50.0%, transparent 50.0%);
#         }#T_82fb0_row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 66.2%, transparent 66.2%);
#         }#T_82fb0_row0_col3,#T_82fb0_row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.8%, red 40.8%, red 50.0%, transparent 50.0%);
#         }#T_82fb0_row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 84.1%, transparent 84.1%);
#         }#T_82fb0_row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 58.2%, transparent 58.2%);
#         }#T_82fb0_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.5%, red 12.5%, red 50.0%, transparent 50.0%);
#         }#T_82fb0_row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 40.3%, red 40.3%, red 50.0%, transparent 50.0%);
#         }#T_82fb0_row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 62.9%, transparent 62.9%);
#         }#T_82fb0_row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.0%, red 41.0%, red 50.0%, transparent 50.0%);
#         }#T_82fb0_row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 61.4%, transparent 61.4%);
#         }#T_82fb0_row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 49.6%, red 49.6%, red 50.0%, transparent 50.0%);
#         }#T_82fb0_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 72.3%, transparent 72.3%);
#         }#T_82fb0_row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.1%, red 12.1%, red 50.0%, transparent 50.0%);
#         }#T_82fb0_row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 59.7%, transparent 59.7%);
#         }#T_82fb0_row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 41.7%, red 41.7%, red 50.0%, transparent 50.0%);
#         }#T_82fb0_row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 35.5%, red 35.5%, red 50.0%, transparent 50.0%);
#         }#T_82fb0_row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 44.9%, red 44.9%, red 50.0%, transparent 50.0%);
#         }#T_82fb0_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 38.8%, red 38.8%, red 50.0%, transparent 50.0%);
#         }#T_82fb0_row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 26.9%, red 26.9%, red 50.0%, transparent 50.0%);
#         }#T_82fb0_row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 53.7%, transparent 53.7%);
#         }#T_82fb0_row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 74.8%, transparent 74.8%);
#         }#T_82fb0_row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.5%, red 46.5%, red 50.0%, transparent 50.0%);
#         }#T_82fb0_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 73.1%, transparent 73.1%);
#         }#T_82fb0_row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 82.0%, transparent 82.0%);
#         }#T_82fb0_row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.3%, red 6.3%, red 50.0%, transparent 50.0%);
#         }#T_82fb0_row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 22.0%, red 22.0%, red 50.0%, transparent 50.0%);
#         }#T_82fb0_row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.8%, red 47.8%, red 50.0%, transparent 50.0%);
#         }#T_82fb0_row4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 36.8%, red 36.8%, red 50.0%, transparent 50.0%);
#         }#T_82fb0_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 66.4%, transparent 66.4%);
#         }#T_82fb0_row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 21.1%, red 21.1%, red 50.0%, transparent 50.0%);
#         }#T_82fb0_row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 45.6%, red 45.6%, red 50.0%, transparent 50.0%);
#         }#T_82fb0_row5_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 90.5%, transparent 90.5%);
#         }#T_82fb0_row5_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 51.9%, transparent 51.9%);
#         }#T_82fb0_row5_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, green 50.0%, green 61.6%, transparent 61.6%);
#         }</style><table id="T_82fb0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>        <th class="col_heading level0 col5" >F</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_82fb0_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_82fb0_row0_col0" class="data row0 col0" >0.333345</td>
#                         <td id="T_82fb0_row0_col1" class="data row0 col1" >-0.629803</td>
#                         <td id="T_82fb0_row0_col2" class="data row0 col2" >0.969120</td>
#                         <td id="T_82fb0_row0_col3" class="data row0 col3" >-0.552186</td>
#                         <td id="T_82fb0_row0_col4" class="data row0 col4" >2.045531</td>
#                         <td id="T_82fb0_row0_col5" class="data row0 col5" >0.493451</td>
#             </tr>
#             <tr>
#                         <th id="T_82fb0_level0_row1" c

# %%
df.style.bar(align="mid", width=50).apply(gold_max, axis=None).applymap(neg_red)
# Out:
# <style  type="text/css" >
# #T_2bdc2_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 30.9%, #d65f5f 30.9%, #d65f5f 35.5%, transparent 35.5%);
#             color: blcck;
#         }#T_2bdc2_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 19.6%, #d65f5f 19.6%, #d65f5f 27.1%, transparent 27.1%);
#             color: red;
#         }#T_2bdc2_row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 36.5%, #d65f5f 36.5%, #d65f5f 50.0%, transparent 50.0%);
#             color: blcck;
#         }#T_2bdc2_row0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 13.7%, #d65f5f 13.7%, #d65f5f 20.4%, transparent 20.4%);
#             color: red;
#         }#T_2bdc2_row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 14.9%, #d65f5f 14.9%, #d65f5f 50.0%, transparent 50.0%);
#             color: blcck;
#         }#T_2bdc2_row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 26.6%, #d65f5f 26.6%, #d65f5f 43.2%, transparent 43.2%);
#             color: blcck;
#         }#T_2bdc2_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 30.9%, transparent 30.9%);
#             color: red;
#         }#T_2bdc2_row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 20.2%, #d65f5f 20.2%, #d65f5f 27.1%, transparent 27.1%);
#             color: red;
#         }#T_2bdc2_row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 36.5%, #d65f5f 36.5%, #d65f5f 47.3%, transparent 47.3%);
#             color: blcck;
#         }#T_2bdc2_row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 13.9%, #d65f5f 13.9%, #d65f5f 20.4%, transparent 20.4%);
#             color: red;
#         }#T_2bdc2_row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 14.9%, #d65f5f 14.9%, #d65f5f 26.7%, transparent 26.7%);
#             color: blcck;
#         }#T_2bdc2_row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.7%, #d65f5f 25.7%, #d65f5f 26.6%, transparent 26.6%);
#             color: red;
#         }#T_2bdc2_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 30.9%, #d65f5f 30.9%, #d65f5f 49.4%, transparent 49.4%);
#             color: blcck;
#         }#T_2bdc2_row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 27.1%, transparent 27.1%);
#             color: red;
#         }#T_2bdc2_row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 36.5%, #d65f5f 36.5%, #d65f5f 44.6%, transparent 44.6%);
#             color: blcck;
#         }#T_2bdc2_row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 14.4%, #d65f5f 14.4%, #d65f5f 20.4%, transparent 20.4%);
#             color: red;
#         }#T_2bdc2_row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.9%, transparent 14.9%);
#             color: red;
#         }#T_2bdc2_row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 16.4%, #d65f5f 16.4%, #d65f5f 26.6%, transparent 26.6%);
#             color: red;
#         }#T_2bdc2_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 21.7%, #d65f5f 21.7%, #d65f5f 30.9%, transparent 30.9%);
#             color: red;
#         }#T_2bdc2_row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 10.6%, #d65f5f 10.6%, #d65f5f 27.1%, transparent 27.1%);
#             color: red;
#         }#T_2bdc2_row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 28.8%, #d65f5f 28.8%, #d65f5f 36.5%, transparent 36.5%);
#             color: red;
#         }#T_2bdc2_row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 20.4%, #d65f5f 20.4%, #d65f5f 23.1%, transparent 23.1%);
#             color: blcck;
#         }#T_2bdc2_row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 14.9%, #d65f5f 14.9%, #d65f5f 40.5%, transparent 40.5%);
#             color: blcck;
#         }#T_2bdc2_row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 19.7%, #d65f5f 19.7%, #d65f5f 26.6%, transparent 26.6%);
#             color: red;
#         }#T_2bdc2_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 30.9%, #d65f5f 30.9%, #d65f5f 50.0%, transparent 50.0%);
#             color: blcck;
#         }#T_2bdc2_row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 27.1%, #d65f5f 27.1%, #d65f5f 50.0%, transparent 50.0%);
#             color: blcck;
#         }#T_2bdc2_row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 36.5%, transparent 36.5%);
#             color: red;
#         }#T_2bdc2_row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.4%, transparent 20.4%);
#             color: red;
#         }#T_2bdc2_row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #d65f5f 12.6%, #d65f5f 14.9%, transparent 14.9%);
#             color: red;
#         }#T_2bdc2_row4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.6%, transparent 26.6%);
#             color: red;
#         }#T_2bdc2_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 30.9%, #d65f5f 30.9%, #d65f5f 44.5%, transparent 44.5%);
#             color: blcck;
#         }#T_2bdc2_row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 6.4%, #d65f5f 6.4%, #d65f5f 27.1%, transparent 27.1%);
#             color: red;
#         }#T_2bdc2_row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 32.8%, #d65f5f 32.8%, #d65f5f 36.5%, transparent 36.5%);
#             color: red;
#         }#T_2bdc2_row5_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 20.4%, #d65f5f 20.4%, #d65f5f 50.0%, transparent 50.0%);
#             background-color:  #c78f2e;
#             color: blcck;
#         }#T_2bdc2_row5_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 14.9%, #d65f5f 14.9%, #d65f5f 16.9%, transparent 16.9%);
#             color: blcck;
#         }#T_2bdc2_row5_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 26.6%, #d65f5f 26.6%, #d65f5f 50.0%, transparent 50.0%);
#             color: blcck;
#         }</style><table id="T_2bdc2_" ><thead>    <tr>        <th class="blank level0" ></th>

# %%
#visualizing NDimnesional Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
from sklearn import manifold

# %%
df = pd.read_csv("/Users/divya/AIML/Cr-03-PythonAndPandasForDataAnalysisAndDataManipulation/Materials/P87-Section-3-Visual-Exploration-Resources/P87-S3-Visual-Exploration-Resources/heart.csv")
target = df["target"].to_numpy()
df = df[["age", "sex", "cp", "trestbps", "chol", "thalach"]]
df.head()
# Out:
#    age  sex  cp  trestbps  chol  thalach
# 0   63    1   3       145   233      150
# 1   37    1   2       130   250      187
# 2   41    0   1       130   204      172
# 3   56    1   1       120   236      178
# 4   57    0   0       120   354      163

# %%
pd.plotting.scatter_matrix(frame= df)
# Out:
# array([[<AxesSubplot:xlabel='age', ylabel='age'>,
#         <AxesSubplot:xlabel='sex', ylabel='age'>,
#         <AxesSubplot:xlabel='cp', ylabel='age'>,
#         <AxesSubplot:xlabel='trestbps', ylabel='age'>,
#         <AxesSubplot:xlabel='chol', ylabel='age'>,
#         <AxesSubplot:xlabel='thalach', ylabel='age'>],
#        [<AxesSubplot:xlabel='age', ylabel='sex'>,
#         <AxesSubplot:xlabel='sex', ylabel='sex'>,
#         <AxesSubplot:xlabel='cp', ylabel='sex'>,
#         <AxesSubplot:xlabel='trestbps', ylabel='sex'>,
#         <AxesSubplot:xlabel='chol', ylabel='sex'>,
#         <AxesSubplot:xlabel='thalach', ylabel='sex'>],
#        [<AxesSubplot:xlabel='age', ylabel='cp'>,
#         <AxesSubplot:xlabel='sex', ylabel='cp'>,
#         <AxesSubplot:xlabel='cp', ylabel='cp'>,
#         <AxesSubplot:xlabel='trestbps', ylabel='cp'>,
#         <AxesSubplot:xlabel='chol', ylabel='cp'>,
#         <AxesSubplot:xlabel='thalach', ylabel='cp'>],
#        [<AxesSubplot:xlabel='age', ylabel='trestbps'>,
#         <AxesSubplot:xlabel='sex', ylabel='trestbps'>,
#         <AxesSubplot:xlabel='cp', ylabel='trestbps'>,
#         <AxesSubplot:xlabel='trestbps', ylabel='trestbps'>,
#         <AxesSubplot:xlabel='chol', ylabel='trestbps'>,
#         <AxesSubplot:xlabel='thalach', ylabel='trestbps'>],
#        [<AxesSubplot:xlabel='age', ylabel='chol'>,
#         <AxesSubplot:xlabel='sex', ylabel='chol'>,
#         <AxesSubplot:xlabel='cp', ylabel='chol'>,
#         <AxesSubplot:xlabel='trestbps', ylabel='chol'>,
#         <AxesSubplot:xlabel='chol', ylabel='chol'>,
#         <AxesSubplot:xlabel='thalach', ylabel='chol'>],
#        [<AxesSubplot:xlabel='age', ylabel='thalach'>,
#         <AxesSubplot:xlabel='sex', ylabel='thalach'>,
#         <AxesSubplot:xlabel='cp', ylabel='thalach'>,
#         <AxesSubplot:xlabel='trestbps', ylabel='thalach'>,
#         <AxesSubplot:xlabel='chol', ylabel='thalach'>,
#         <AxesSubplot:xlabel='thalach', ylabel='thalach'>]], dtype=object)

# %%
df.corr()
# Out:
#                age       sex        cp  trestbps      chol   thalach
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678 -0.398522
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912 -0.044020
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.295762
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174 -0.046698
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000 -0.009940
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940  1.000000

# %%
sns.heatmap(df.corr(), annot=True, fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.corr(), annot=True, fmt="0.2f", square=True)
# Out:
# <AxesSubplot:>

# %%
np.random.seed(0)
n = 2000
t = np.linspace(0, 20, n)
x = t * np.sin(t) + 0.2 * np.random.normal(size=n)
y = t * np.cos(t) + 0.2 * np.random.normal(size=n)
z = np.log(t + 1) * np.sin(np.sqrt(t)) + 0.1 * np.random.normal(size=n)
a = np.log(t + 1) * np.cos(np.sqrt(t)) + 0.1 * np.random.normal(size=n)

df2 = pd.DataFrame({"x": x, "y": y, "z": z, "a": a})
data = df2.to_numpy()

# %%
pd.plotting.scatter_matrix(df2)
# Out:
# array([[<AxesSubplot:xlabel='x', ylabel='x'>,
#         <AxesSubplot:xlabel='y', ylabel='x'>,
#         <AxesSubplot:xlabel='z', ylabel='x'>,
#         <AxesSubplot:xlabel='a', ylabel='x'>],
#        [<AxesSubplot:xlabel='x', ylabel='y'>,
#         <AxesSubplot:xlabel='y', ylabel='y'>,
#         <AxesSubplot:xlabel='z', ylabel='y'>,
#         <AxesSubplot:xlabel='a', ylabel='y'>],
#        [<AxesSubplot:xlabel='x', ylabel='z'>,
#         <AxesSubplot:xlabel='y', ylabel='z'>,
#         <AxesSubplot:xlabel='z', ylabel='z'>,
#         <AxesSubplot:xlabel='a', ylabel='z'>],
#        [<AxesSubplot:xlabel='x', ylabel='a'>,
#         <AxesSubplot:xlabel='y', ylabel='a'>,
#         <AxesSubplot:xlabel='z', ylabel='a'>,
#         <AxesSubplot:xlabel='a', ylabel='a'>]], dtype=object)

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(x,y,z,c=t,s=3+a)

# %%
methods = [
    ("LLE", manifold.LocallyLinearEmbedding(n_neighbors=20, method='standard')),
    ("LTSA", manifold.LocallyLinearEmbedding(n_neighbors=20, method='ltsa')),
    ("Hessian LLE", manifold.LocallyLinearEmbedding(n_neighbors=20, method='hessian')),
    ("Modified LLE", manifold.LocallyLinearEmbedding(n_neighbors=20, method='modified')),
    ("Isomap", manifold.Isomap()),
    ("MDS", manifold.MDS(n_init=1)),
    ("SE", manifold.SpectralEmbedding()),
    ("t-SNE", manifold.TSNE()),
]

fig, axes = plt.subplots(nrows=2, ncols=4)
for (name, method), ax in zip(methods, axes.flatten()):
    print(f"Running {name}")
    Y = method.fit_transform(data)
    ax.scatter(Y[:, 0], Y[:, 1], c=t)
    ax.set_title(name)
    ax.set_xticklabels([])
    ax.set_yticklabels([])
# Out:
# Running LLE
# Running LTSA
# Running Hessian LLE
# Running Modified LLE
# Running Isomap
# Running MDS
# Running SE
# Running t-SNE

# %%
fig, axes = plt.subplots(nrows=2, ncols=4)
for (name, method), ax in zip(methods, axes.flatten()):
    print(f"Running {name}")
    try:
        Y = method.fit_transform(df.to_numpy())
        ax.scatter(Y[:, 0], Y[:, 1], c=target)
    except Exception:
        print(f"Method {name} failed")
    ax.set_title(name)
    ax.set_xticklabels([])
    ax.set_yticklabels([])
# Out:
# Running LLE
# Running LTSA
# Method LTSA failed
# Running Hessian LLE
# C:\Users\divya\anaconda3\lib\site-packages\scipy\sparse\linalg\eigen\arpack\arpack.py:936: LinAlgWarning: Diagonal number 86 is exactly zero. Singular matrix.
#   self.M_lu = lu_factor(M)
# Method Hessian LLE failed
# Running Modified LLE
# Running Isomap
# Running MDS
# Running SE
# Running t-SNE
